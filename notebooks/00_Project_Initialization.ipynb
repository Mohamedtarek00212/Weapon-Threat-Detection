# %% [markdown]
# # Phase 1 — Project Initialization
#
# Creates a timestamped experiment record with the active configuration, hardware selection, runtime metadata, and log file. It does not inspect, process, or modify the dataset.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
from weapon_threat_detection.config import load_config
from weapon_threat_detection.experiments import create_experiment

config_path = ROOT / 'configs' / 'project.yaml'
config = load_config(config_path)
experiment = create_experiment(config_path, config['experiments']['default_name'])
print(f'Experiment: {experiment.name}')
print(f'Device: {experiment.device.name} ({experiment.device.backend})')
print(f'Metadata: {experiment.metadata_path}')
print(f'Log: {experiment.log_path}')
